# %%
# %load_ext nb_black
# !pip install nb_black
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
columns = [
    "Features",
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "CV_Accuracy",
    "CV_Accuracy_std",
]
rf = pd.read_csv(" RF_Result.csv")
rf.columns = columns
rf["Model"] = "RF"

svm = pd.read_csv(" SVM_Result.csv")
svm.columns = columns
svm["Model"] = "SVM"

xgb = pd.read_csv(" XGB_Result.csv")
xgb.columns = columns
xgb["Model"] = "XGB"

# %%
originalFeatures = [
    "FPG",
    "HbA1c",
    "Triglyceride",
    "BMI",
    "r-GTP gamma",
    "Uric acid",
    "Smoking",
    "Drinking",
    "Physical activity",
    "Family history",
    "SEX",
    "AGE",
]

# %%
result = (
    pd.concat([rf, svm, xgb])
    .sort_values(by=["Accuracy"], ascending=False)
    .reset_index(drop=True)
)
result = result.iloc[:20, :]
result
# Out:
#                       Features  Accuracy  Precision    Recall  F1-score  \
# 0   [0, 1, 2, 3, 4, 6, 10, 11]  0.750000   0.757830  0.750000  0.753037
# 1    [0, 1, 3, 4, 5, 6, 9, 11]  0.748333   0.745505  0.748333  0.746536
# 2   [0, 1, 3, 4, 6, 9, 10, 11]  0.748333   0.755439  0.748333  0.751105
# 3   [0, 1, 2, 6, 8, 9, 10, 11]  0.748333   0.745505  0.748333  0.746536
# 4   [0, 1, 2, 3, 5, 8, 10, 11]  0.746667   0.743966  0.746667  0.744852
# 5   [0, 1, 2, 3, 4, 9, 10, 11]  0.746667   0.746236  0.746667  0.746170
# 6   [0, 1, 3, 4, 6, 9, 10, 11]  0.745000   0.742793  0.745000  0.743671
# 7   [0, 1, 2, 6, 8, 9, 10, 11]  0.745000   0.744725  0.745000  0.744536
# 8   [0, 1, 3, 4, 8, 9, 10, 11]  0.745000   0.743665  0.745000  0.744104
# 9    [0, 1, 3, 4, 5, 6, 9, 11]  0.745000   0.743809  0.745000  0.744145
# 10  [0, 1, 2, 3, 5, 6, 10, 11]  0.745000   0.742389  0.745000  0.743300
# 11  [0, 1, 3, 4, 5, 6, 10, 11]  0.745000   0.742843  0.745000  0.743630
# 12  [0, 1, 3, 4, 5, 6, 10, 11]  0.743333   0.750443  0.743333  0.746016
# 13  [0, 1, 3, 4, 6, 9, 10, 11]  0.743333   0.742585  0.743333  0.742719
# 14  [0, 1, 2, 3, 5, 9, 10, 11]  0.743333   0.741508  0.743333  0.742164
# 15  [0, 1, 2, 3, 4, 6, 10, 11]  0.741667   0.740173  0.741667  0.740759
# 16  [0, 1, 2, 3, 5, 6, 10, 11]  0.740000   0.737433  0.740000  0.738540
# 17  [0, 1, 2, 3, 4, 9, 10, 11]  0.740000   0.744957  0.740000  0.742011
# 18  [0, 1, 3, 4, 5, 6, 10, 11]  0.740000   0.738139  0.740000  0.738881
# 19  [0, 1, 2, 3, 4, 9, 10, 11]  0.738333   0.735811  0.738333  0.736743
#
#     CV_Accuracy  CV_Accuracy_std Model
# 0      0.749696         0.037506    RF
# 1      0.721112         0.029883   SVM
# 2      0.745143         0.037465    RF
# 3      0.719399         0.030772   SVM
# 4      0.710469         0.038938   XGB
# 5      0.710411         0.038892   XGB
# 6      0.718173         0.027881   SVM
# 7      0.705624         0.039073   XGB
# 8      0.709457         0.039375   XGB
# 9      0.710761         0.038026   XGB
# 10     0.710839         0.039708   XGB
# 11     0.710119         0.037955   XGB
# 12     0.748704         0.038160    RF
# 13     0.710002         0.038508   XGB
# 14     0.711053         0.038075   XGB
# 15     0.718854         0.027997   SVM
# 16     0.721034         0.029047   SVM
# 17     0.748801         0.037473    RF
# 18     0.719866         0.028018   SVM
# 19     0.718446         0.027820   SVM

# %%
for i in range(result.shape[0]):
    temp = list(
        str(result.iloc[i, 0])
        .replace("[", "")
        .replace("]", "")
        .replace(" ", "")
        .split(",")
    )
    temp_changed = []
    for j in range(len(temp)):
        temp_changed.append(originalFeatures[int(temp[j])])
    result.iloc[i, 0] = str(temp_changed)
result
# Out:
#                                              Features  Accuracy  Precision  \
# 0   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.750000   0.757830
# 1   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.748333   0.745505
# 2   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Smokin...  0.748333   0.755439
# 3   ['FPG', 'HbA1c', 'Triglyceride', 'Smoking', 'P...  0.748333   0.745505
# 4   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'Uric ...  0.746667   0.743966
# 5   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.746667   0.746236
# 6   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Smokin...  0.745000   0.742793
# 7   ['FPG', 'HbA1c', 'Triglyceride', 'Smoking', 'P...  0.745000   0.744725
# 8   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Physic...  0.745000   0.743665
# 9   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.745000   0.743809
# 10  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'Uric ...  0.745000   0.742389
# 11  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.745000   0.742843
# 12  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.743333   0.750443
# 13  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Smokin...  0.743333   0.742585
# 14  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'Uric ...  0.743333   0.741508
# 15  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.741667   0.740173
# 16  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'Uric ...  0.740000   0.737433
# 17  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.740000   0.744957
# 18  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.740000   0.738139
# 19  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.738333   0.735811
#
#       Recall  F1-score  CV_Accuracy  CV_Accuracy_std Model
# 0   0.750000  0.753037     0.749696         0.037506    RF
# 1   0.748333  0.746536     0.721112         0.029883   SVM
# 2   0.748333  0.751105     0.745143         0.037465    RF
# 3   0.748333  0.746536     0.719399         0.030772   SVM
# 4   0.746667  0.744852     0.710469         0.038938   XGB
# 5   0.746667  0.746170     0.710411         0.038892   XGB
# 6   0.745000  0.743671     0.718173         0.027881   SVM
# 7   0.745000  0.744536     0.705624         0.039073   XGB
# 8   0.745000  0.744104     0.709457         0.039375   XGB
# 9   0.745000  0.744145     0.710761         0.038026   XGB
# 10  0.745000  0.743300     0.710839         0.039708   XGB
# 11  0.745000  0.743630     0.710119         0.037955   XGB
# 12  0.743333  0.746016     0.748704         0.038160    RF
# 13  0.743333  0.742719     0.710002         0.038508   XGB
# 14  0.743333  0.742164     0.711053         0.038075   XGB
# 15  0.741667  0.740759     0.718854         0.027997   SVM
# 16  0.740000  0.738540     0.721034         0.029047   SVM
# 17  0.740000  0.742011     0.748801         0.037473    RF
# 18  0.740000  0.738881     0.719866         0.028018   SVM
# 19  0.738333  0.736743     0.718446         0.027820   SVM

# %%
result.to_csv("Final_result.csv", index=False)
