# %%
# %load_ext nb_black
# !pip install nb_black
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
columns = [
    "Features",
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "CV_Accuracy",
    "CV_Accuracy_std",
]
rf = pd.read_csv(" RF_Result.csv")
rf.columns = columns
rf["Model"] = "RF"

svm = pd.read_csv(" SVM_Result.csv")
svm.columns = columns
svm["Model"] = "SVM"

xgb = pd.read_csv(" XGB_Result.csv")
xgb.columns = columns
xgb["Model"] = "XGB"

# %%
originalFeatures = [
    "FPG",
    "HbA1c",
    "Triglyceride",
    "BMI",
    "r-GTP gamma",
    "Uric acid",
    "Smoking",
    "Drinking",
    "Physical activity",
    "Family history",
    "SEX",
    "AGE",
]

# %%
result = (
    pd.concat([rf, svm, xgb])
    .sort_values(by=["Accuracy"], ascending=False)
    .reset_index(drop=True)
)
result = result.iloc[:20, :]
result
# Out:
#           Features  Accuracy  Precision    Recall  F1-score  CV_Accuracy  \
# 0    (0, 1, 9, 10)  0.760000   0.757689  0.760000  0.758620     0.704278
# 1    (0, 1, 5, 10)  0.755000   0.752301  0.755000  0.753382     0.721908
# 2    (0, 1, 6, 10)  0.753333   0.751046  0.753333  0.752044     0.720060
# 3   (0, 1, 10, 11)  0.751667   0.749126  0.751667  0.750126     0.715352
# 4    (0, 1, 3, 11)  0.750000   0.746727  0.750000  0.747357     0.714788
# 5    (0, 1, 6, 10)  0.750000   0.749882  0.750000  0.749795     0.736988
# 6    (0, 1, 9, 10)  0.748333   0.748150  0.748333  0.748159     0.734245
# 7    (0, 1, 7, 10)  0.748333   0.756493  0.748333  0.751408     0.759832
# 8    (0, 1, 8, 10)  0.746667   0.747778  0.746667  0.747178     0.736891
# 9   (0, 1, 10, 11)  0.745000   0.744673  0.745000  0.744651     0.700409
# 10   (0, 1, 7, 10)  0.745000   0.742445  0.745000  0.743505     0.722570
# 11   (0, 1, 7, 10)  0.743333   0.743564  0.743333  0.743367     0.737552
# 12    (0, 1, 3, 6)  0.743333   0.739635  0.743333  0.740743     0.722453
# 13   (0, 1, 2, 10)  0.743333   0.742740  0.743333  0.742845     0.736910
# 14    (0, 1, 6, 7)  0.743333   0.756672  0.743333  0.747836     0.761505
# 15   (0, 1, 5, 10)  0.743333   0.754492  0.743333  0.747203     0.768627
# 16   (0, 1, 6, 11)  0.741667   0.740849  0.741667  0.741018     0.700837
# 17   (0, 1, 2, 10)  0.741667   0.739067  0.741667  0.740190     0.723620
# 18    (0, 1, 4, 7)  0.741667   0.741554  0.741667  0.741428     0.738448
# 19    (0, 1, 3, 9)  0.740000   0.736256  0.740000  0.737176     0.720332
#
#     CV_Accuracy_std Model
# 0          0.049793   SVM
# 1          0.009433   SVM
# 2          0.011065   SVM
# 3          0.029488   SVM
# 4          0.028496   SVM
# 5          0.013480   XGB
# 6          0.011740   XGB
# 7          0.017803    RF
# 8          0.014830   XGB
# 9          0.038182   XGB
# 10         0.008775   SVM
# 11         0.012217   XGB
# 12         0.009067   SVM
# 13         0.013288   XGB
# 14         0.017005    RF
# 15         0.017035    RF
# 16         0.038835   XGB
# 17         0.009736   SVM
# 18         0.013541   XGB
# 19         0.009619   SVM

# %%
for i in range(result.shape[0]):
    temp = list(
        str(result.iloc[i, 0])
        .replace("(", "")
        .replace(")", "")
        .replace(" ", "")
        .split(",")
    )
    temp_changed = []
    for j in range(len(temp)):
        temp_changed.append(originalFeatures[int(temp[j])])
    result.iloc[i, 0] = str(temp_changed)
result
# Out:
#                                         Features  Accuracy  Precision  \
# 0      ['FPG', 'HbA1c', 'Family history', 'SEX']  0.760000   0.757689
# 1           ['FPG', 'HbA1c', 'Uric acid', 'SEX']  0.755000   0.752301
# 2             ['FPG', 'HbA1c', 'Smoking', 'SEX']  0.753333   0.751046
# 3                 ['FPG', 'HbA1c', 'SEX', 'AGE']  0.751667   0.749126
# 4                 ['FPG', 'HbA1c', 'BMI', 'AGE']  0.750000   0.746727
# 5             ['FPG', 'HbA1c', 'Smoking', 'SEX']  0.750000   0.749882
# 6      ['FPG', 'HbA1c', 'Family history', 'SEX']  0.748333   0.748150
# 7            ['FPG', 'HbA1c', 'Drinking', 'SEX']  0.748333   0.756493
# 8   ['FPG', 'HbA1c', 'Physical activity', 'SEX']  0.746667   0.747778
# 9                 ['FPG', 'HbA1c', 'SEX', 'AGE']  0.745000   0.744673
# 10           ['FPG', 'HbA1c', 'Drinking', 'SEX']  0.745000   0.742445
# 11           ['FPG', 'HbA1c', 'Drinking', 'SEX']  0.743333   0.743564
# 12            ['FPG', 'HbA1c', 'BMI', 'Smoking']  0.743333   0.739635
# 13       ['FPG', 'HbA1c', 'Triglyceride', 'SEX']  0.743333   0.742740
# 14       ['FPG', 'HbA1c', 'Smoking', 'Drinking']  0.743333   0.756672
# 15          ['FPG', 'HbA1c', 'Uric acid', 'SEX']  0.743333   0.754492
# 16            ['FPG', 'HbA1c', 'Smoking', 'AGE']  0.741667   0.740849
# 17       ['FPG', 'HbA1c', 'Triglyceride', 'SEX']  0.741667   0.739067
# 18   ['FPG', 'HbA1c', 'r-GTP gamma', 'Drinking']  0.741667   0.741554
# 19     ['FPG', 'HbA1c', 'BMI', 'Family history']  0.740000   0.736256
#
#       Recall  F1-score  CV_Accuracy  CV_Accuracy_std Model
# 0   0.760000  0.758620     0.704278         0.049793   SVM
# 1   0.755000  0.753382     0.721908         0.009433   SVM
# 2   0.753333  0.752044     0.720060         0.011065   SVM
# 3   0.751667  0.750126     0.715352         0.029488   SVM
# 4   0.750000  0.747357     0.714788         0.028496   SVM
# 5   0.750000  0.749795     0.736988         0.013480   XGB
# 6   0.748333  0.748159     0.734245         0.011740   XGB
# 7   0.748333  0.751408     0.759832         0.017803    RF
# 8   0.746667  0.747178     0.736891         0.014830   XGB
# 9   0.745000  0.744651     0.700409         0.038182   XGB
# 10  0.745000  0.743505     0.722570         0.008775   SVM
# 11  0.743333  0.743367     0.737552         0.012217   XGB
# 12  0.743333  0.740743     0.722453         0.009067   SVM
# 13  0.743333  0.742845     0.736910         0.013288   XGB
# 14  0.743333  0.747836     0.761505         0.017005    RF
# 15  0.743333  0.747203     0.768627         0.017035    RF
# 16  0.741667  0.741018     0.700837         0.038835   XGB
# 17  0.741667  0.740190     0.723620         0.009736   SVM
# 18  0.741667  0.741428     0.738448         0.013541   XGB
# 19  0.740000  0.737176     0.720332         0.009619   SVM

# %%
result.to_csv("Final_result.csv", index=False)
