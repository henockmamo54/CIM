# %%
# %load_ext nb_black
# !pip install nb_black
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
columns = [
    "Features",
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "CV_Accuracy",
    "CV_Accuracy_std",
]
rf = pd.read_csv(" RF_Result.csv")
rf.columns = columns
rf["Model"] = "RF"

svm = pd.read_csv(" SVM_Result.csv")
svm.columns = columns
svm["Model"] = "SVM"

xgb = pd.read_csv(" XGB_Result.csv")
xgb.columns = columns
xgb["Model"] = "XGB"

# %%
originalFeatures = [
    "FPG",
    "HbA1c",
    "Triglyceride",
    "BMI",
    "r-GTP gamma",
    "Uric acid",
    "Smoking",
    "Drinking",
    "Physical activity",
    "Family history",
    "SEX",
    "AGE",
]

# %%
result = (
    pd.concat([rf, svm, xgb])
    .sort_values(by=["Accuracy"], ascending=False)
    .reset_index(drop=True)
)
result = result.iloc[:20, :]
result
# Out:
#    Features  Accuracy  Precision    Recall  F1-score  CV_Accuracy  \
# 0    (0, 1)  0.738333   0.736859  0.738333  0.737319     0.731423
# 1    (0, 1)  0.728333   0.723740  0.728333  0.725060     0.718289
# 2    (0, 3)  0.728333   0.729142  0.728333  0.728106     0.709883
# 3    (0, 1)  0.725000   0.737428  0.725000  0.729582     0.758003
# 4   (0, 10)  0.723333   0.721136  0.723333  0.722131     0.699940
# 5    (0, 4)  0.721667   0.731986  0.721667  0.725562     0.742787
# 6    (0, 6)  0.721667   0.722168  0.721667  0.720788     0.698092
# 7    (0, 6)  0.720000   0.720011  0.720000  0.719997     0.678380
# 8    (0, 6)  0.716667   0.717207  0.716667  0.716756     0.697508
# 9    (0, 4)  0.715000   0.712955  0.715000  0.713838     0.711129
# 10  (0, 11)  0.715000   0.714471  0.715000  0.714422     0.686302
# 11   (0, 3)  0.713333   0.710961  0.713333  0.711417     0.697702
# 12  (0, 11)  0.713333   0.715421  0.713333  0.714014     0.663946
# 13  (0, 10)  0.710000   0.707991  0.710000  0.708727     0.696496
# 14  (0, 11)  0.708333   0.716299  0.708333  0.711193     0.688093
# 15   (0, 7)  0.703333   0.704035  0.703333  0.703420     0.701653
# 16   (0, 9)  0.703333   0.696856  0.703333  0.699311     0.696944
# 17   (0, 8)  0.703333   0.706092  0.703333  0.704495     0.704124
# 18   (0, 7)  0.703333   0.707294  0.703333  0.705002     0.711790
# 19   (0, 8)  0.700000   0.698829  0.700000  0.699264     0.698812
#
#     CV_Accuracy_std Model
# 0          0.013011   XGB
# 1          0.011718   SVM
# 2          0.011764   XGB
# 3          0.021614    RF
# 4          0.008664    RF
# 5          0.014433    RF
# 6          0.012045    RF
# 7          0.051115   SVM
# 8          0.010317   XGB
# 9          0.011511   XGB
# 10         0.032041   SVM
# 11         0.007190   SVM
# 12         0.044941   XGB
# 13         0.007449   XGB
# 14         0.043874    RF
# 15         0.009053   XGB
# 16         0.008477    RF
# 17         0.011985    RF
# 18         0.009843    RF
# 19         0.010267   XGB

# %%
for i in range(result.shape[0]):
    temp = list(
        str(result.iloc[i, 0])
        .replace("(", "")
        .replace(")", "")
        .replace(" ", "")
        .split(",")
    )
    temp_changed = []
    for j in range(len(temp)):
        temp_changed.append(originalFeatures[int(temp[j])])
    result.iloc[i, 0] = str(temp_changed)
result
# Out:
#                         Features  Accuracy  Precision    Recall  F1-score  \
# 0               ['FPG', 'HbA1c']  0.738333   0.736859  0.738333  0.737319
# 1               ['FPG', 'HbA1c']  0.728333   0.723740  0.728333  0.725060
# 2                 ['FPG', 'BMI']  0.728333   0.729142  0.728333  0.728106
# 3               ['FPG', 'HbA1c']  0.725000   0.737428  0.725000  0.729582
# 4                 ['FPG', 'SEX']  0.723333   0.721136  0.723333  0.722131
# 5         ['FPG', 'r-GTP gamma']  0.721667   0.731986  0.721667  0.725562
# 6             ['FPG', 'Smoking']  0.721667   0.722168  0.721667  0.720788
# 7             ['FPG', 'Smoking']  0.720000   0.720011  0.720000  0.719997
# 8             ['FPG', 'Smoking']  0.716667   0.717207  0.716667  0.716756
# 9         ['FPG', 'r-GTP gamma']  0.715000   0.712955  0.715000  0.713838
# 10                ['FPG', 'AGE']  0.715000   0.714471  0.715000  0.714422
# 11                ['FPG', 'BMI']  0.713333   0.710961  0.713333  0.711417
# 12                ['FPG', 'AGE']  0.713333   0.715421  0.713333  0.714014
# 13                ['FPG', 'SEX']  0.710000   0.707991  0.710000  0.708727
# 14                ['FPG', 'AGE']  0.708333   0.716299  0.708333  0.711193
# 15           ['FPG', 'Drinking']  0.703333   0.704035  0.703333  0.703420
# 16     ['FPG', 'Family history']  0.703333   0.696856  0.703333  0.699311
# 17  ['FPG', 'Physical activity']  0.703333   0.706092  0.703333  0.704495
# 18           ['FPG', 'Drinking']  0.703333   0.707294  0.703333  0.705002
# 19  ['FPG', 'Physical activity']  0.700000   0.698829  0.700000  0.699264
#
#     CV_Accuracy  CV_Accuracy_std Model
# 0      0.731423         0.013011   XGB
# 1      0.718289         0.011718   SVM
# 2      0.709883         0.011764   XGB
# 3      0.758003         0.021614    RF
# 4      0.699940         0.008664    RF
# 5      0.742787         0.014433    RF
# 6      0.698092         0.012045    RF
# 7      0.678380         0.051115   SVM
# 8      0.697508         0.010317   XGB
# 9      0.711129         0.011511   XGB
# 10     0.686302         0.032041   SVM
# 11     0.697702         0.007190   SVM
# 12     0.663946         0.044941   XGB
# 13     0.696496         0.007449   XGB
# 14     0.688093         0.043874    RF
# 15     0.701653         0.009053   XGB
# 16     0.696944         0.008477    RF
# 17     0.704124         0.011985    RF
# 18     0.711790         0.009843    RF
# 19     0.698812         0.010267   XGB

# %%
result.to_csv("Final_result.csv", index=False)
