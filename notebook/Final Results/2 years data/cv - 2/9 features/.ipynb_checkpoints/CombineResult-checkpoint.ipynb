# %%
# %load_ext nb_black
# !pip install nb_black
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
columns = [
    "Features",
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "CV_Accuracy",
    "CV_Accuracy_std",
]
rf = pd.read_csv(" RF_Result.csv")
rf.columns = columns
rf["Model"] = "RF"

svm = pd.read_csv(" SVM_Result.csv")
svm.columns = columns
svm["Model"] = "SVM"

xgb = pd.read_csv(" XGB_Result.csv")
xgb.columns = columns
xgb["Model"] = "XGB"

# %%
originalFeatures = [
    "FPG",
    "HbA1c",
    "Triglyceride",
    "BMI",
    "r-GTP gamma",
    "Uric acid",
    "Smoking",
    "Drinking",
    "Physical activity",
    "Family history",
    "SEX",
    "AGE",
]

# %%
result = (
    pd.concat([rf, svm, xgb])
    .sort_values(by=["Accuracy"], ascending=False)
    .reset_index(drop=True)
)
result = result.iloc[:20, :]
result
# Out:
#                          Features  Accuracy  Precision    Recall  F1-score  \
# 0   [0, 1, 3, 5, 6, 8, 9, 10, 11]  0.748333   0.745484  0.748333  0.746592
# 1   [0, 1, 3, 4, 5, 6, 9, 10, 11]  0.748333   0.746257  0.748333  0.747002
# 2   [0, 1, 2, 3, 4, 6, 9, 10, 11]  0.746667   0.755339  0.746667  0.749918
# 3    [0, 1, 2, 3, 4, 5, 6, 9, 11]  0.746667   0.743700  0.746667  0.744736
# 4   [0, 1, 3, 4, 5, 6, 8, 10, 11]  0.743333   0.741362  0.743333  0.742036
# 5   [0, 1, 2, 3, 4, 6, 9, 10, 11]  0.743333   0.742276  0.743333  0.742597
# 6   [0, 1, 2, 3, 5, 6, 8, 10, 11]  0.741667   0.740129  0.741667  0.740616
# 7    [0, 1, 3, 4, 5, 6, 7, 8, 11]  0.741667   0.739485  0.741667  0.740286
# 8   [0, 1, 3, 4, 5, 6, 9, 10, 11]  0.741667   0.738718  0.741667  0.739880
# 9    [0, 1, 3, 4, 5, 6, 7, 8, 11]  0.741667   0.751396  0.741667  0.745307
# 10   [0, 1, 2, 3, 4, 5, 6, 9, 11]  0.740000   0.737903  0.740000  0.738579
# 11  [0, 1, 3, 4, 6, 7, 9, 10, 11]  0.740000   0.736672  0.740000  0.737838
# 12  [0, 1, 3, 4, 5, 8, 9, 10, 11]  0.740000   0.747542  0.740000  0.742795
# 13  [0, 1, 3, 4, 6, 7, 8, 10, 11]  0.740000   0.737378  0.740000  0.738297
# 14  [0, 1, 3, 4, 6, 7, 9, 10, 11]  0.740000   0.745520  0.740000  0.742244
# 15  [0, 1, 2, 3, 5, 6, 8, 10, 11]  0.740000   0.737156  0.740000  0.738317
# 16  [0, 1, 2, 3, 4, 6, 9, 10, 11]  0.738333   0.736285  0.738333  0.737074
# 17  [0, 1, 3, 4, 6, 7, 8, 10, 11]  0.738333   0.746792  0.738333  0.741582
# 18  [0, 1, 3, 4, 5, 8, 9, 10, 11]  0.738333   0.735091  0.738333  0.736283
# 19  [0, 1, 3, 4, 5, 6, 8, 10, 11]  0.738333   0.735811  0.738333  0.736743
#
#     CV_Accuracy  CV_Accuracy_std Model
# 0      0.722221         0.029433   SVM
# 1      0.711792         0.038768   XGB
# 2      0.750747         0.036586    RF
# 3      0.721306         0.029779   SVM
# 4      0.711753         0.040316   XGB
# 5      0.709146         0.038705   XGB
# 6      0.710916         0.040027   XGB
# 7      0.725159         0.029568   SVM
# 8      0.722026         0.029101   SVM
# 9      0.752790         0.038764    RF
# 10     0.710255         0.037989   XGB
# 11     0.724964         0.029276   SVM
# 12     0.750319         0.038220    RF
# 13     0.726482         0.030316   SVM
# 14     0.749852         0.039004    RF
# 15     0.722610         0.029694   SVM
# 16     0.718991         0.028369   SVM
# 17     0.749443         0.039015    RF
# 18     0.711325         0.038782   XGB
# 19     0.722980         0.029643   SVM

# %%
for i in range(result.shape[0]):
    temp = list(
        str(result.iloc[i, 0])
        .replace("[", "")
        .replace("]", "")
        .replace(" ", "")
        .split(",")
    )
    temp_changed = []
    for j in range(len(temp)):
        temp_changed.append(originalFeatures[int(temp[j])])
    result.iloc[i, 0] = str(temp_changed)
result
# Out:
#                                              Features  Accuracy  Precision  \
# 0   ['FPG', 'HbA1c', 'BMI', 'Uric acid', 'Smoking'...  0.748333   0.745484
# 1   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.748333   0.746257
# 2   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.746667   0.755339
# 3   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.746667   0.743700
# 4   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.743333   0.741362
# 5   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.743333   0.742276
# 6   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'Uric ...  0.741667   0.740129
# 7   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.741667   0.739485
# 8   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.741667   0.738718
# 9   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.741667   0.751396
# 10  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.740000   0.737903
# 11  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Smokin...  0.740000   0.736672
# 12  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.740000   0.747542
# 13  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Smokin...  0.740000   0.737378
# 14  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Smokin...  0.740000   0.745520
# 15  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'Uric ...  0.740000   0.737156
# 16  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.738333   0.736285
# 17  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Smokin...  0.738333   0.746792
# 18  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.738333   0.735091
# 19  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.738333   0.735811
#
#       Recall  F1-score  CV_Accuracy  CV_Accuracy_std Model
# 0   0.748333  0.746592     0.722221         0.029433   SVM
# 1   0.748333  0.747002     0.711792         0.038768   XGB
# 2   0.746667  0.749918     0.750747         0.036586    RF
# 3   0.746667  0.744736     0.721306         0.029779   SVM
# 4   0.743333  0.742036     0.711753         0.040316   XGB
# 5   0.743333  0.742597     0.709146         0.038705   XGB
# 6   0.741667  0.740616     0.710916         0.040027   XGB
# 7   0.741667  0.740286     0.725159         0.029568   SVM
# 8   0.741667  0.739880     0.722026         0.029101   SVM
# 9   0.741667  0.745307     0.752790         0.038764    RF
# 10  0.740000  0.738579     0.710255         0.037989   XGB
# 11  0.740000  0.737838     0.724964         0.029276   SVM
# 12  0.740000  0.742795     0.750319         0.038220    RF
# 13  0.740000  0.738297     0.726482         0.030316   SVM
# 14  0.740000  0.742244     0.749852         0.039004    RF
# 15  0.740000  0.738317     0.722610         0.029694   SVM
# 16  0.738333  0.737074     0.718991         0.028369   SVM
# 17  0.738333  0.741582     0.749443         0.039015    RF
# 18  0.738333  0.736283     0.711325         0.038782   XGB
# 19  0.738333  0.736743     0.722980         0.029643   SVM

# %%
result.to_csv("Final_result.csv", index=False)
