# %%
# %load_ext nb_black
# !pip install nb_black
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
columns = [
    "Features",
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "CV_Accuracy",
    "CV_Accuracy_std",
]
rf = pd.read_csv(" RF_Result.csv")
rf.columns = columns
rf["Model"] = "RF"

svm = pd.read_csv(" SVM_Result.csv")
svm.columns = columns
svm["Model"] = "SVM"

xgb = pd.read_csv(" XGB_Result.csv")
xgb.columns = columns
xgb["Model"] = "XGB"

# %%
originalFeatures = [
    "FPG",
    "HbA1c",
    "Triglyceride",
    "BMI",
    "r-GTP gamma",
    "Uric acid",
    "Smoking",
    "Drinking",
    "Physical activity",
    "Family history",
    "SEX",
    "AGE",
]

# %%
result = (
    pd.concat([rf, svm, xgb])
    .sort_values(by=["Accuracy"], ascending=False)
    .reset_index(drop=True)
)
result = result.iloc[:20, :]
result
# Out:
#                 Features  Accuracy  Precision    Recall  F1-score  \
# 0   [0, 1, 8, 9, 10, 11]  0.755000   0.752045  0.755000  0.753144
# 1    [0, 1, 6, 8, 9, 10]  0.753333   0.750579  0.753333  0.751730
# 2   [0, 1, 6, 9, 10, 11]  0.750000   0.747095  0.750000  0.748230
# 3   [0, 1, 3, 6, 10, 11]  0.750000   0.757699  0.750000  0.752964
# 4    [0, 1, 6, 8, 9, 10]  0.748333   0.756292  0.748333  0.751399
# 5    [0, 1, 6, 8, 9, 10]  0.746667   0.747500  0.746667  0.747015
# 6   [0, 1, 6, 9, 10, 11]  0.746667   0.756391  0.746667  0.750209
# 7   [0, 1, 3, 8, 10, 11]  0.745000   0.755157  0.745000  0.748627
# 8   [0, 1, 2, 5, 10, 11]  0.745000   0.753439  0.745000  0.748139
# 9   [0, 1, 3, 8, 10, 11]  0.745000   0.744467  0.745000  0.744541
# 10  [0, 1, 2, 3, 10, 11]  0.745000   0.743896  0.745000  0.744190
# 11  [0, 1, 8, 9, 10, 11]  0.745000   0.744388  0.745000  0.744412
# 12  [0, 1, 2, 9, 10, 11]  0.745000   0.753738  0.745000  0.748173
# 13  [0, 1, 3, 5, 10, 11]  0.745000   0.742817  0.745000  0.743463
# 14  [0, 1, 6, 9, 10, 11]  0.743333   0.742562  0.743333  0.742755
# 15  [0, 1, 2, 9, 10, 11]  0.743333   0.740328  0.743333  0.741518
# 16  [0, 1, 3, 9, 10, 11]  0.741667   0.740750  0.741667  0.741047
# 17  [0, 1, 3, 6, 10, 11]  0.741667   0.740564  0.741667  0.740859
# 18  [0, 1, 2, 9, 10, 11]  0.741667   0.741072  0.741667  0.741090
# 19  [0, 1, 2, 5, 10, 11]  0.741667   0.739538  0.741667  0.740366
#
#     CV_Accuracy  CV_Accuracy_std Model
# 0      0.717998         0.030395   SVM
# 1      0.722726         0.012690   SVM
# 2      0.715021         0.029289   SVM
# 3      0.742652         0.038801    RF
# 4      0.759248         0.016567    RF
# 5      0.736327         0.014513   XGB
# 6      0.731600         0.040424    RF
# 7      0.741057         0.037545    RF
# 8      0.746271         0.037361    RF
# 9      0.705721         0.039350   XGB
# 10     0.708893         0.038333   XGB
# 11     0.703075         0.038817   XGB
# 12     0.740921         0.037791    RF
# 13     0.708990         0.038999   XGB
# 14     0.702121         0.037905   XGB
# 15     0.714807         0.028699   SVM
# 16     0.705702         0.039501   XGB
# 17     0.707122         0.039520   XGB
# 18     0.703892         0.037263   XGB
# 19     0.706402         0.039095   XGB

# %%
for i in range(result.shape[0]):
    temp = list(
        str(result.iloc[i, 0])
        .replace("[", "")
        .replace("]", "")
        .replace(" ", "")
        .split(",")
    )
    temp_changed = []
    for j in range(len(temp)):
        temp_changed.append(originalFeatures[int(temp[j])])
    result.iloc[i, 0] = str(temp_changed)
result
# Out:
#                                              Features  Accuracy  Precision  \
# 0   ['FPG', 'HbA1c', 'Physical activity', 'Family ...  0.755000   0.752045
# 1   ['FPG', 'HbA1c', 'Smoking', 'Physical activity...  0.753333   0.750579
# 2   ['FPG', 'HbA1c', 'Smoking', 'Family history', ...  0.750000   0.747095
# 3    ['FPG', 'HbA1c', 'BMI', 'Smoking', 'SEX', 'AGE']  0.750000   0.757699
# 4   ['FPG', 'HbA1c', 'Smoking', 'Physical activity...  0.748333   0.756292
# 5   ['FPG', 'HbA1c', 'Smoking', 'Physical activity...  0.746667   0.747500
# 6   ['FPG', 'HbA1c', 'Smoking', 'Family history', ...  0.746667   0.756391
# 7   ['FPG', 'HbA1c', 'BMI', 'Physical activity', '...  0.745000   0.755157
# 8   ['FPG', 'HbA1c', 'Triglyceride', 'Uric acid', ...  0.745000   0.753439
# 9   ['FPG', 'HbA1c', 'BMI', 'Physical activity', '...  0.745000   0.744467
# 10  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'SEX',...  0.745000   0.743896
# 11  ['FPG', 'HbA1c', 'Physical activity', 'Family ...  0.745000   0.744388
# 12  ['FPG', 'HbA1c', 'Triglyceride', 'Family histo...  0.745000   0.753738
# 13  ['FPG', 'HbA1c', 'BMI', 'Uric acid', 'SEX', 'A...  0.745000   0.742817
# 14  ['FPG', 'HbA1c', 'Smoking', 'Family history', ...  0.743333   0.742562
# 15  ['FPG', 'HbA1c', 'Triglyceride', 'Family histo...  0.743333   0.740328
# 16  ['FPG', 'HbA1c', 'BMI', 'Family history', 'SEX...  0.741667   0.740750
# 17   ['FPG', 'HbA1c', 'BMI', 'Smoking', 'SEX', 'AGE']  0.741667   0.740564
# 18  ['FPG', 'HbA1c', 'Triglyceride', 'Family histo...  0.741667   0.741072
# 19  ['FPG', 'HbA1c', 'Triglyceride', 'Uric acid', ...  0.741667   0.739538
#
#       Recall  F1-score  CV_Accuracy  CV_Accuracy_std Model
# 0   0.755000  0.753144     0.717998         0.030395   SVM
# 1   0.753333  0.751730     0.722726         0.012690   SVM
# 2   0.750000  0.748230     0.715021         0.029289   SVM
# 3   0.750000  0.752964     0.742652         0.038801    RF
# 4   0.748333  0.751399     0.759248         0.016567    RF
# 5   0.746667  0.747015     0.736327         0.014513   XGB
# 6   0.746667  0.750209     0.731600         0.040424    RF
# 7   0.745000  0.748627     0.741057         0.037545    RF
# 8   0.745000  0.748139     0.746271         0.037361    RF
# 9   0.745000  0.744541     0.705721         0.039350   XGB
# 10  0.745000  0.744190     0.708893         0.038333   XGB
# 11  0.745000  0.744412     0.703075         0.038817   XGB
# 12  0.745000  0.748173     0.740921         0.037791    RF
# 13  0.745000  0.743463     0.708990         0.038999   XGB
# 14  0.743333  0.742755     0.702121         0.037905   XGB
# 15  0.743333  0.741518     0.714807         0.028699   SVM
# 16  0.741667  0.741047     0.705702         0.039501   XGB
# 17  0.741667  0.740859     0.707122         0.039520   XGB
# 18  0.741667  0.741090     0.703892         0.037263   XGB
# 19  0.741667  0.740366     0.706402         0.039095   XGB

# %%
result.to_csv("Final_result.csv", index=False)
