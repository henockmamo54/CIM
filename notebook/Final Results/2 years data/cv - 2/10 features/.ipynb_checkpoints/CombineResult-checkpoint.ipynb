# %%
# %load_ext nb_black
# !pip install nb_black
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
columns = [
    "Features",
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "CV_Accuracy",
    "CV_Accuracy_std",
]
rf = pd.read_csv(" RF_Result.csv")
rf.columns = columns
rf["Model"] = "RF"

svm = pd.read_csv(" SVM_Result.csv")
svm.columns = columns
svm["Model"] = "SVM"

xgb = pd.read_csv(" XGB_Result.csv")
xgb.columns = columns
xgb["Model"] = "XGB"

# %%
originalFeatures = [
    "FPG",
    "HbA1c",
    "Triglyceride",
    "BMI",
    "r-GTP gamma",
    "Uric acid",
    "Smoking",
    "Drinking",
    "Physical activity",
    "Family history",
    "SEX",
    "AGE",
]

# %%
result = (
    pd.concat([rf, svm, xgb])
    .sort_values(by=["Accuracy"], ascending=False)
    .reset_index(drop=True)
)
result = result.iloc[:20, :]
result
# Out:
#                             Features  Accuracy  Precision    Recall  F1-score  \
# 0   [0, 1, 3, 4, 5, 6, 8, 9, 10, 11]  0.746667   0.744402  0.746667  0.745182
# 1   [0, 1, 2, 3, 4, 5, 6, 8, 10, 11]  0.746667   0.745539  0.746667  0.745788
# 2   [0, 1, 3, 4, 6, 7, 8, 9, 10, 11]  0.745000   0.742594  0.745000  0.743464
# 3   [0, 1, 3, 4, 5, 6, 8, 9, 10, 11]  0.743333   0.740311  0.743333  0.741452
# 4   [0, 1, 2, 3, 4, 6, 7, 9, 10, 11]  0.743333   0.749080  0.743333  0.745688
# 5   [0, 1, 2, 3, 4, 5, 8, 9, 10, 11]  0.743333   0.740133  0.743333  0.741058
# 6   [0, 1, 3, 4, 5, 6, 7, 9, 10, 11]  0.743333   0.741256  0.743333  0.741919
# 7   [0, 1, 2, 3, 5, 6, 8, 9, 10, 11]  0.743333   0.741927  0.743333  0.742401
# 8   [0, 1, 2, 3, 4, 5, 6, 9, 10, 11]  0.741667   0.739690  0.741667  0.740442
# 9   [0, 1, 2, 3, 4, 5, 6, 9, 10, 11]  0.741667   0.739462  0.741667  0.740123
# 10  [0, 1, 3, 4, 5, 6, 7, 9, 10, 11]  0.741667   0.739020  0.741667  0.739951
# 11  [0, 1, 3, 4, 6, 7, 8, 9, 10, 11]  0.740000   0.737378  0.740000  0.738297
# 12  [0, 1, 2, 3, 5, 6, 8, 9, 10, 11]  0.740000   0.736902  0.740000  0.738083
# 13  [0, 1, 2, 3, 4, 5, 6, 7, 10, 11]  0.738333   0.735854  0.738333  0.736821
# 14  [0, 1, 2, 3, 4, 5, 6, 8, 10, 11]  0.738333   0.735811  0.738333  0.736743
# 15  [0, 1, 2, 3, 4, 5, 8, 9, 10, 11]  0.736667   0.734476  0.736667  0.735284
# 16   [0, 1, 2, 3, 4, 5, 6, 7, 9, 11]  0.736667   0.733726  0.736667  0.734740
# 17  [0, 1, 2, 3, 4, 5, 6, 9, 10, 11]  0.736667   0.743385  0.736667  0.739250
# 18  [0, 1, 2, 3, 4, 5, 8, 9, 10, 11]  0.736667   0.741423  0.736667  0.738561
# 19  [0, 1, 2, 3, 4, 6, 7, 9, 10, 11]  0.736667   0.734936  0.736667  0.735550
#
#     CV_Accuracy  CV_Accuracy_std Model
# 0      0.713310         0.039626   XGB
# 1      0.711033         0.039770   XGB
# 2      0.714419         0.038490   XGB
# 3      0.723855         0.029110   SVM
# 4      0.750980         0.037760    RF
# 5      0.712356         0.038046   XGB
# 6      0.714555         0.039116   XGB
# 7      0.712064         0.039538   XGB
# 8      0.722435         0.029150   SVM
# 9      0.712142         0.037914   XGB
# 10     0.725665         0.029335   SVM
# 11     0.726618         0.030543   SVM
# 12     0.720139         0.028690   SVM
# 13     0.725801         0.029282   SVM
# 14     0.718562         0.031919   SVM
# 15     0.721890         0.028302   SVM
# 16     0.726190         0.030364   SVM
# 17     0.753179         0.036585    RF
# 18     0.752362         0.037770    RF
# 19     0.712045         0.038287   XGB

# %%
for i in range(result.shape[0]):
    temp = list(
        str(result.iloc[i, 0])
        .replace("[", "")
        .replace("]", "")
        .replace(" ", "")
        .split(",")
    )
    temp_changed = []
    for j in range(len(temp)):
        temp_changed.append(originalFeatures[int(temp[j])])
    result.iloc[i, 0] = str(temp_changed)
result
# Out:
#                                              Features  Accuracy  Precision  \
# 0   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.746667   0.744402
# 1   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.746667   0.745539
# 2   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Smokin...  0.745000   0.742594
# 3   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.743333   0.740311
# 4   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.743333   0.749080
# 5   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.743333   0.740133
# 6   ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.743333   0.741256
# 7   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'Uric ...  0.743333   0.741927
# 8   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.741667   0.739690
# 9   ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.741667   0.739462
# 10  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Uric a...  0.741667   0.739020
# 11  ['FPG', 'HbA1c', 'BMI', 'r-GTP gamma', 'Smokin...  0.740000   0.737378
# 12  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'Uric ...  0.740000   0.736902
# 13  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.738333   0.735854
# 14  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.738333   0.735811
# 15  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.736667   0.734476
# 16  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.736667   0.733726
# 17  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.736667   0.743385
# 18  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.736667   0.741423
# 19  ['FPG', 'HbA1c', 'Triglyceride', 'BMI', 'r-GTP...  0.736667   0.734936
#
#       Recall  F1-score  CV_Accuracy  CV_Accuracy_std Model
# 0   0.746667  0.745182     0.713310         0.039626   XGB
# 1   0.746667  0.745788     0.711033         0.039770   XGB
# 2   0.745000  0.743464     0.714419         0.038490   XGB
# 3   0.743333  0.741452     0.723855         0.029110   SVM
# 4   0.743333  0.745688     0.750980         0.037760    RF
# 5   0.743333  0.741058     0.712356         0.038046   XGB
# 6   0.743333  0.741919     0.714555         0.039116   XGB
# 7   0.743333  0.742401     0.712064         0.039538   XGB
# 8   0.741667  0.740442     0.722435         0.029150   SVM
# 9   0.741667  0.740123     0.712142         0.037914   XGB
# 10  0.741667  0.739951     0.725665         0.029335   SVM
# 11  0.740000  0.738297     0.726618         0.030543   SVM
# 12  0.740000  0.738083     0.720139         0.028690   SVM
# 13  0.738333  0.736821     0.725801         0.029282   SVM
# 14  0.738333  0.736743     0.718562         0.031919   SVM
# 15  0.736667  0.735284     0.721890         0.028302   SVM
# 16  0.736667  0.734740     0.726190         0.030364   SVM
# 17  0.736667  0.739250     0.753179         0.036585    RF
# 18  0.736667  0.738561     0.752362         0.037770    RF
# 19  0.736667  0.735550     0.712045         0.038287   XGB

# %%
result.to_csv("Final_result.csv", index=False)
