# %%
# %load_ext nb_black
# !pip install nb_black
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
columns = [
    "Features",
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "CV_Accuracy",
    "CV_Accuracy_std",
]
rf = pd.read_csv(" RF_Result.csv")
rf.columns = columns
rf["Model"] = "RF"

svm = pd.read_csv(" SVM_Result.csv")
svm.columns = columns
svm["Model"] = "SVM"

xgb = pd.read_csv(" XGB_Result.csv")
xgb.columns = columns
xgb["Model"] = "XGB"

# %%
originalFeatures = [
    "FPG",
    "HbA1c",
    "Triglyceride",
    "BMI",
    "r-GTP gamma",
    "Uric acid",
    "Smoking",
    "Drinking",
    "Physical activity",
    "Family history",
    "SEX",
    "AGE",
]

# %%
result = (
    pd.concat([rf, svm, xgb])
    .sort_values(by=["Accuracy"], ascending=False)
    .reset_index(drop=True)
)
result = result.iloc[:20, :]
result
# Out:
#              Features  Accuracy  Precision    Recall  F1-score  CV_Accuracy  \
# 0    [0, 1, 8, 9, 10]  0.758333   0.755509  0.758333  0.756649     0.721091
# 1   [0, 1, 9, 10, 11]  0.755000   0.752259  0.755000  0.753241     0.714924
# 2    [0, 1, 5, 8, 10]  0.751667   0.749388  0.751667  0.750349     0.723192
# 3    [0, 1, 6, 8, 10]  0.751667   0.749205  0.751667  0.750256     0.721986
# 4    [0, 1, 7, 9, 10]  0.750000   0.755348  0.750000  0.752155     0.759910
# 5    [0, 1, 7, 8, 10]  0.750000   0.746877  0.750000  0.748064     0.726792
# 6   [0, 1, 5, 10, 11]  0.748333   0.745537  0.748333  0.746671     0.715527
# 7   [0, 1, 9, 10, 11]  0.748333   0.747348  0.748333  0.747486     0.701654
# 8    [0, 1, 2, 8, 10]  0.746667   0.753054  0.746667  0.749063     0.766934
# 9    [0, 1, 5, 8, 10]  0.746667   0.746712  0.746667  0.746680     0.736229
# 10   [0, 1, 6, 8, 10]  0.746667   0.747014  0.746667  0.746818     0.737377
# 11   [0, 1, 7, 9, 10]  0.746667   0.743988  0.746667  0.745061     0.724224
# 12   [0, 1, 2, 8, 10]  0.745000   0.741890  0.745000  0.743074     0.723815
# 13   [0, 1, 8, 9, 10]  0.745000   0.746169  0.745000  0.745501     0.734965
# 14  [0, 1, 5, 10, 11]  0.745000   0.757828  0.745000  0.749235     0.741329
# 15   [0, 1, 7, 8, 10]  0.743333   0.743795  0.743333  0.743450     0.737027
# 16  [0, 1, 9, 10, 11]  0.743333   0.753988  0.743333  0.747176     0.732184
# 17   [0, 1, 5, 6, 11]  0.743333   0.739382  0.743333  0.740633     0.716734
# 18   [0, 1, 5, 6, 11]  0.741667   0.750744  0.741667  0.745008     0.743509
# 19  [0, 1, 5, 10, 11]  0.741667   0.740121  0.741667  0.740614     0.704418
#
#     CV_Accuracy_std Model
# 0          0.011755   SVM
# 1          0.029480   SVM
# 2          0.010679   SVM
# 3          0.011354   SVM
# 4          0.015994    RF
# 5          0.010137   SVM
# 6          0.028238   SVM
# 7          0.037741   XGB
# 8          0.014790    RF
# 9          0.014288   XGB
# 10         0.014827   XGB
# 11         0.009871   SVM
# 12         0.010229   SVM
# 13         0.014086   XGB
# 14         0.039067    RF
# 15         0.013421   XGB
# 16         0.040375    RF
# 17         0.030901   SVM
# 18         0.039667    RF
# 19         0.039073   XGB

# %%
for i in range(result.shape[0]):
    temp = list(
        str(result.iloc[i, 0])
        .replace("[", "")
        .replace("]", "")
        .replace(" ", "")
        .split(",")
    )
    temp_changed = []
    for j in range(len(temp)):
        temp_changed.append(originalFeatures[int(temp[j])])
    result.iloc[i, 0] = str(temp_changed)
result
# Out:
#                                              Features  Accuracy  Precision  \
# 0   ['FPG', 'HbA1c', 'Physical activity', 'Family ...  0.758333   0.755509
# 1    ['FPG', 'HbA1c', 'Family history', 'SEX', 'AGE']  0.755000   0.752259
# 2   ['FPG', 'HbA1c', 'Uric acid', 'Physical activi...  0.751667   0.749388
# 3   ['FPG', 'HbA1c', 'Smoking', 'Physical activity...  0.751667   0.749205
# 4   ['FPG', 'HbA1c', 'Drinking', 'Family history',...  0.750000   0.755348
# 5   ['FPG', 'HbA1c', 'Drinking', 'Physical activit...  0.750000   0.746877
# 6         ['FPG', 'HbA1c', 'Uric acid', 'SEX', 'AGE']  0.748333   0.745537
# 7    ['FPG', 'HbA1c', 'Family history', 'SEX', 'AGE']  0.748333   0.747348
# 8   ['FPG', 'HbA1c', 'Triglyceride', 'Physical act...  0.746667   0.753054
# 9   ['FPG', 'HbA1c', 'Uric acid', 'Physical activi...  0.746667   0.746712
# 10  ['FPG', 'HbA1c', 'Smoking', 'Physical activity...  0.746667   0.747014
# 11  ['FPG', 'HbA1c', 'Drinking', 'Family history',...  0.746667   0.743988
# 12  ['FPG', 'HbA1c', 'Triglyceride', 'Physical act...  0.745000   0.741890
# 13  ['FPG', 'HbA1c', 'Physical activity', 'Family ...  0.745000   0.746169
# 14        ['FPG', 'HbA1c', 'Uric acid', 'SEX', 'AGE']  0.745000   0.757828
# 15  ['FPG', 'HbA1c', 'Drinking', 'Physical activit...  0.743333   0.743795
# 16   ['FPG', 'HbA1c', 'Family history', 'SEX', 'AGE']  0.743333   0.753988
# 17    ['FPG', 'HbA1c', 'Uric acid', 'Smoking', 'AGE']  0.743333   0.739382
# 18    ['FPG', 'HbA1c', 'Uric acid', 'Smoking', 'AGE']  0.741667   0.750744
# 19        ['FPG', 'HbA1c', 'Uric acid', 'SEX', 'AGE']  0.741667   0.740121
#
#       Recall  F1-score  CV_Accuracy  CV_Accuracy_std Model
# 0   0.758333  0.756649     0.721091         0.011755   SVM
# 1   0.755000  0.753241     0.714924         0.029480   SVM
# 2   0.751667  0.750349     0.723192         0.010679   SVM
# 3   0.751667  0.750256     0.721986         0.011354   SVM
# 4   0.750000  0.752155     0.759910         0.015994    RF
# 5   0.750000  0.748064     0.726792         0.010137   SVM
# 6   0.748333  0.746671     0.715527         0.028238   SVM
# 7   0.748333  0.747486     0.701654         0.037741   XGB
# 8   0.746667  0.749063     0.766934         0.014790    RF
# 9   0.746667  0.746680     0.736229         0.014288   XGB
# 10  0.746667  0.746818     0.737377         0.014827   XGB
# 11  0.746667  0.745061     0.724224         0.009871   SVM
# 12  0.745000  0.743074     0.723815         0.010229   SVM
# 13  0.745000  0.745501     0.734965         0.014086   XGB
# 14  0.745000  0.749235     0.741329         0.039067    RF
# 15  0.743333  0.743450     0.737027         0.013421   XGB
# 16  0.743333  0.747176     0.732184         0.040375    RF
# 17  0.743333  0.740633     0.716734         0.030901   SVM
# 18  0.741667  0.745008     0.743509         0.039667    RF
# 19  0.741667  0.740614     0.704418         0.039073   XGB

# %%
result.to_csv("Final_result.csv", index=False)
