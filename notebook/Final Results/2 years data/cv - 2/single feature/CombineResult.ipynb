# %%
# %load_ext nb_black
# !pip install nb_black
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
columns = [
    "Features",
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "CV_Accuracy",
    "CV_Accuracy_std",
]
rf = pd.read_csv("RF_Result.csv")
rf.columns = columns
rf["Model"] = "RF"

svm = pd.read_csv("SVM_Result.csv")
svm.columns = columns
svm["Model"] = "SVM"

xgb = pd.read_csv("XGB_Result.csv")
xgb.columns = columns
xgb["Model"] = "XGB"

# %%
originalFeatures = [
    "FPG",
    "HbA1c",
    "Triglyceride",
    "BMI",
    "r-GTP gamma",
    "Uric acid",
    "Smoking",
    "Drinking",
    "Physical activity",
    "Family history",
    "SEX",
    "AGE",
]

# %%
result = (
    pd.concat([rf, svm, xgb])
    .sort_values(by=["Accuracy"], ascending=False)
    .reset_index(drop=True)
)
result = result.iloc[:20, :]
result
# Out:
#     Features  Accuracy  Precision    Recall  F1-score  CV_Accuracy  \
# 0        0.0  0.698333   0.697648  0.698333  0.697983     0.694959
# 1        0.0  0.698333   0.698354  0.698333  0.697346     0.630355
# 2        0.0  0.698333   0.697648  0.698333  0.697983     0.694803
# 3        1.0  0.641667   0.628507  0.641667  0.627233     0.629969
# 4        1.0  0.628333   0.621197  0.628333  0.623710     0.629561
# 5        1.0  0.616667   0.614503  0.616667  0.614919     0.634425
# 6        4.0  0.540000   0.536449  0.540000  0.536213     0.508221
# 7        4.0  0.528333   0.524831  0.528333  0.526240     0.518904
# 8        2.0  0.476667   0.471573  0.476667  0.473488     0.496080
# 9        3.0  0.475000   0.460397  0.475000  0.464616     0.484911
# 10       2.0  0.468333   0.468247  0.468333  0.439664     0.459810
# 11       4.0  0.466667   0.488333  0.466667  0.430403     0.459012
# 12       3.0  0.466667   0.449018  0.466667  0.449146     0.475182
# 13       3.0  0.463333   0.453176  0.463333  0.455925     0.496294
# 14      10.0  0.461667   0.340749  0.461667  0.368154     0.444107
# 15      10.0  0.461667   0.340749  0.461667  0.368154     0.444107
# 16       2.0  0.446667   0.436623  0.446667  0.438551     0.529742
# 17      11.0  0.430000   0.430806  0.430000  0.394236     0.384781
# 18      11.0  0.426667   0.405426  0.426667  0.393464     0.409861
# 19       6.0  0.423333   0.417229  0.423333  0.413028     0.418209
#
#     CV_Accuracy_std Model
# 0          0.009402    RF
# 1          0.055877   SVM
# 2          0.009328   XGB
# 3          0.010002   XGB
# 4          0.012494   SVM
# 5          0.009715    RF
# 6          0.006416   XGB
# 7          0.005404    RF
# 8          0.010817   XGB
# 9          0.009646   XGB
# 10         0.007071   SVM
# 11         0.007522   SVM
# 12         0.010443   SVM
# 13         0.010255    RF
# 14         0.004258   XGB
# 15         0.004258    RF
# 16         0.010753    RF
# 17         0.031184    RF
# 18         0.038191   SVM
# 19         0.012172   XGB

# %%
for i in range(result.shape[0]):
    result.iloc[i, 0] = originalFeatures[int(result.iloc[i, 0])]
result
# Out:
#         Features  Accuracy  Precision    Recall  F1-score  CV_Accuracy  \
# 0            FPG  0.698333   0.697648  0.698333  0.697983     0.694959
# 1            FPG  0.698333   0.698354  0.698333  0.697346     0.630355
# 2            FPG  0.698333   0.697648  0.698333  0.697983     0.694803
# 3          HbA1c  0.641667   0.628507  0.641667  0.627233     0.629969
# 4          HbA1c  0.628333   0.621197  0.628333  0.623710     0.629561
# 5          HbA1c  0.616667   0.614503  0.616667  0.614919     0.634425
# 6    r-GTP gamma  0.540000   0.536449  0.540000  0.536213     0.508221
# 7    r-GTP gamma  0.528333   0.524831  0.528333  0.526240     0.518904
# 8   Triglyceride  0.476667   0.471573  0.476667  0.473488     0.496080
# 9            BMI  0.475000   0.460397  0.475000  0.464616     0.484911
# 10  Triglyceride  0.468333   0.468247  0.468333  0.439664     0.459810
# 11   r-GTP gamma  0.466667   0.488333  0.466667  0.430403     0.459012
# 12           BMI  0.466667   0.449018  0.466667  0.449146     0.475182
# 13           BMI  0.463333   0.453176  0.463333  0.455925     0.496294
# 14           SEX  0.461667   0.340749  0.461667  0.368154     0.444107
# 15           SEX  0.461667   0.340749  0.461667  0.368154     0.444107
# 16  Triglyceride  0.446667   0.436623  0.446667  0.438551     0.529742
# 17           AGE  0.430000   0.430806  0.430000  0.394236     0.384781
# 18           AGE  0.426667   0.405426  0.426667  0.393464     0.409861
# 19       Smoking  0.423333   0.417229  0.423333  0.413028     0.418209
#
#     CV_Accuracy_std Model
# 0          0.009402    RF
# 1          0.055877   SVM
# 2          0.009328   XGB
# 3          0.010002   XGB
# 4          0.012494   SVM
# 5          0.009715    RF
# 6          0.006416   XGB
# 7          0.005404    RF
# 8          0.010817   XGB
# 9          0.009646   XGB
# 10         0.007071   SVM
# 11         0.007522   SVM
# 12         0.010443   SVM
# 13         0.010255    RF
# 14         0.004258   XGB
# 15         0.004258    RF
# 16         0.010753    RF
# 17         0.031184    RF
# 18         0.038191   SVM
# 19         0.012172   XGB

# %%
result.to_csv("Final_result.csv", index=False)
